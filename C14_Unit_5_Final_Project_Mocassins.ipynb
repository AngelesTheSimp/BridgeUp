# %% [markdown]
# # Unit 5 Anthropology - Final Project

# %% [markdown]
# Exploring the AMNH collections database for mocassins and reporting their color combinations.
#
# Create at least two functions to find the following using Claire Heckel's moccasin data:
# 1. How many color combinations are used on moccasins? How many moccasins have a combination of 3 colors?
# 2. Which color combinations occur most often in our moccasins data (min/max)?
# 3. What are the three most common pairs of motifs on moccasins? What are the least common?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
 
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ClairesMoccasinData - Data.csv")

# %%
combo2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2_color_combos.txt")
combo3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/3_color_combos.txt")
motif3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/3_motif_combos.txt")
combo4 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/4_color_combos.txt")
motif4 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/4_motif_combos.txt")
combo5 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/5_color_combos.txt.crdownload")
motif5 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/5_motif_combos.txt")

# %%
data.head(5)
# Out:
#       CATNO  ACCYEAR  CULTURE  ...  MOTIF_TWISTED  MOTIF_VERTEBRAE  OTHER
# 0  502.5947        0        1  ...              0                0      0
# 1  502.5947        0        1  ...              0                0      0
# 2    50.623     1899        1  ...              0                0      0
# 3    50.381     1899        1  ...              0                0      0
# 4    50.643     1899        1  ...              0                0      0
#
# [5 rows x 91 columns]

# %%
Plains = data.loc[data["CULTURE"]== 5]

# %%
Plains.head()
# Out:
#        CATNO  ACCYEAR  CULTURE  ...  MOTIF_TWISTED  MOTIF_VERTEBRAE  OTHER
# 79  502.4411     1940        5  ...              0                0      0
# 80  502.4582     1942        5  ...              0                0      0
# 81   502.393     1936        5  ...              0                0      0
# 82  502.4608     1942        5  ...              0                0      0
# 83  502.5343     1947        5  ...              0                0      0
#
# [5 rows x 91 columns]

# %%
data.columns

# %%
drop = ['ACCYEAR', 'CULTURE', 'LOCALE','SIZE', 'GENDER', 'BEADED', 'QUILLED',
       'PIGMENT1', 'TONGUETYPE', 'TONGUESEWN', 'CUFFTYPE', 'CUFFSEWN', 'LACES',
       'FRINGE', 'HEELTABS', 'DECOLAYOUT', 'BORDERMOTIF', 'BORDERROWS',
       'TOEMARKER']

Data = data.drop(drop, axis=1)

print(Data)
# Out:
#         CATNO  BLACK  TR_CRYSTAL  ...  MOTIF_TWISTED  MOTIF_VERTEBRAE  OTHER
# 0    502.5947      0           0  ...              0                0      0
# 1    502.5947      0           0  ...              0                0      0
# 2      50.623      0           0  ...              0                0      0
# 3      50.381      1           0  ...              0                0      0
# 4      50.643      0           0  ...              0                0      0
# ..        ...    ...         ...  ...            ...              ...    ...
# 436   50.6008      0           1  ...              0                0      0
# 437   50.6069      0           0  ...              0                0      0
# 438    50.603      1           0  ...              0                0      0
# 439   50.6061      0           0  ...              0                0      0
# 440  501.7371      1           0  ...              0                0      0
#
# [441 rows x 72 columns]

# %%
Data.head()
# Out:
#       CATNO  BLACK  TR_CRYSTAL  ...  MOTIF_TWISTED  MOTIF_VERTEBRAE  OTHER
# 0  502.5947      0           0  ...              0                0      0
# 1  502.5947      0           0  ...              0                0      0
# 2    50.623      0           0  ...              0                0      0
# 3    50.381      1           0  ...              0                0      0
# 4    50.643      0           0  ...              0                0      0
#
# [5 rows x 72 columns]

# %%
Data.head()
plains_colors = Data
plains_motifs = Data
plainColors = ['BLACK', 'TR_CRYSTAL', 'WHITE', 'PINK',
       'TR_RED', 'RED', 'TR_DKRED', 'ORANGE', 'YELLOW', 'TR_ORANGE',
       'TR_YELLOW', 'DKYELLOW', 'TR_TOPAZ', 'BROWN', 'TR_DKBROWN', 'TR_GREEN',
       'LTGREEN', 'TR_MEDGREEN', 'GREEN', 'TR_PEACOCKBL', 'TURQUOISE',
       'LTBLUE', 'POWDERBLUE', 'TR_TURQBLUE', 'STEELBLUE', 'MEDBLUE',
       'ROYALBLUE', 'TR_COBALT', 'NAVYBLUE', 'TR_DKMTBLUE', 'TR_DKPURPLE',
       'LAVENDER', 'SEAGREEN', 'FACETBRASS', 'REDWHITEINT']
plaingMotifs = ['MOTIF_ANTELOPEHOOF', 'MOTIF_ARROW', 'MOTIF_BIRD', 'MOTIF_BOX',
       'MOTIF_BOXPLOT', 'MOTIF_CHECKER', 'MOTIF_CHEVRON', 'MOTIF_CROSSBAR',
       'MOTIF_DIAMO9', 'MOTIF_DRAGONFLY', 'MOTIF_ELKHOOF', 'MOTIF_HOURGLASS',
       'MOTIF_FEATHER', 'MOTIF_FILLEDUP', 'MOTIF_FULLPOINTS', 'MOTIF_HALFSTAR',
       'MOTIF_HEARTLUNGS', 'MOTIF_HORSETRACKS', 'MOTIF_IBAR', 'MOTIF_LEAF',
       'MOTIF_LIGHTNING', 'MOTIF_LONGCHECKER', 'MOTIF_MORNINGSTAR',
       'MOTIF_MOUNTAIN', 'MOTIF_POINTS', 'MOTIF_RABBITEARS',
       'MOTIF_RABBITTRACKS', 'MOTIF_SLANTBAR', 'MOTIF_SQUARECROSS',
       'MOTIF_STRIPES', 'MOTIF_TIPI', 'MOTIF_TRIANGLES', 'MOTIF_TURTLE',
       'MOTIF_TWISTED', 'MOTIF_VERTEBRAE', 'OTHER']

# %%
plains_colors = plains_colors.drop(plaingMotifs, axis = 1).reset_index()
plains_motifs = plains_motifs.drop(plainColors, axis = 1).reset_index()

# %%
plains_colors.columns
# Out:
# Index(['index', 'CATNO', 'BLACK', 'TR_CRYSTAL', 'WHITE', 'PINK', 'TR_RED',
#        'RED', 'TR_DKRED', 'ORANGE', 'YELLOW', 'TR_ORANGE', 'TR_YELLOW',
#        'DKYELLOW', 'TR_TOPAZ', 'BROWN', 'TR_DKBROWN', 'TR_GREEN', 'LTGREEN',
#        'TR_MEDGREEN', 'GREEN', 'TR_PEACOCKBL', 'TURQUOISE', 'LTBLUE',
#        'POWDERBLUE', 'TR_TURQBLUE', 'STEELBLUE', 'MEDBLUE', 'ROYALBLUE',
#        'TR_COBALT', 'NAVYBLUE', 'TR_DKMTBLUE', 'TR_DKPURPLE', 'LAVENDER',
#        'SEAGREEN', 'FACETBRASS', 'REDWHITEINT'],
#       dtype='object')

# %%
plains_motifs.columns
# Out:
# Index(['index', 'CATNO', 'MOTIF_ANTELOPEHOOF', 'MOTIF_ARROW', 'MOTIF_BIRD',
#        'MOTIF_BOX', 'MOTIF_BOXPLOT', 'MOTIF_CHECKER', 'MOTIF_CHEVRON',
#        'MOTIF_CROSSBAR', 'MOTIF_DIAMO9', 'MOTIF_DRAGONFLY', 'MOTIF_ELKHOOF',
#        'MOTIF_HOURGLASS', 'MOTIF_FEATHER', 'MOTIF_FILLEDUP',
#        'MOTIF_FULLPOINTS', 'MOTIF_HALFSTAR', 'MOTIF_HEARTLUNGS',
#        'MOTIF_HORSETRACKS', 'MOTIF_IBAR', 'MOTIF_LEAF', 'MOTIF_LIGHTNING',
#        'MOTIF_LONGCHECKER', 'MOTIF_MORNINGSTAR', 'MOTIF_MOUNTAIN',
#        'MOTIF_POINTS', 'MOTIF_RABBITEARS', 'MOTIF_RABBITTRACKS',
#        'MOTIF_SLANTBAR', 'MOTIF_SQUARECROSS', 'MOTIF_STRIPES', 'MOTIF_TIPI',
#        'MOTIF_TRIANGLES', 'MOTIF_TURTLE', 'MOTIF_TWISTED', 'MOTIF_VERTEBRAE',
#        'OTHER'],
#       dtype='object')

# %%
plains_colors.head()
# Out:
#    index     CATNO  BLACK  ...  SEAGREEN  FACETBRASS  REDWHITEINT
# 0      0  502.5947      0  ...         0           0            0
# 1      1  502.5947      0  ...         0           0            0
# 2      2    50.623      0  ...         0           0            0
# 3      3    50.381      1  ...         0           0            1
# 4      4    50.643      0  ...         0           0            1
#
# [5 rows x 37 columns]

# %%
plains_motifs.head()
# Out:
#    index     CATNO  MOTIF_ANTELOPEHOOF  ...  MOTIF_TWISTED  MOTIF_VERTEBRAE  OTHER
# 0      0  502.5947                   0  ...              0                0      0
# 1      1  502.5947                   0  ...              0                0      0
# 2      2    50.623                   0  ...              0                0      0
# 3      3    50.381                   0  ...              0                0      0
# 4      4    50.643                   0  ...              0                0      0
#
# [5 rows x 38 columns]

# %%
color_list = ['BLACK', 'TR_CRYSTAL', 'WHITE', 'PINK', 'TR_RED', 'RED',
       'TR_DKRED', 'ORANGE', 'YELLOW', 'TR_ORANGE', 'TR_YELLOW', 'DKYELLOW',
       'TR_TOPAZ', 'BROWN', 'TR_DKBROWN', 'TR_GREEN', 'LTGREEN', 'TR_MEDGREEN',
       'GREEN', 'TR_PEACOCKBL', 'TURQUOISE', 'LTBLUE', 'POWDERBLUE',
       'TR_TURQBLUE', 'STEELBLUE', 'MEDBLUE', 'ROYALBLUE', 'TR_COBALT',
       'NAVYBLUE', 'TR_DKMTBLUE', 'TR_DKPURPLE', 'LAVENDER', 'SEAGREEN',
       'FACETBRASS', 'REDWHITEINT']

# %%
moc_dict = {}
for i in range(len(plains_colors)):
  for j in color_list:
    if plains_colors[j][i]==1:
      moc_dict[plains_colors["CATINO"][i]].append
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CATINO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-8828950c0236> in <module>()
# ...

# %%
if i = o:
  j="RED"
  plains_colors["READ"][0]=1
  plains_colors[j][i] == 1
  maccdict[]
